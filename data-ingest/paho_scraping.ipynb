# %%
import camelot
import matplotlib
# %matplotlib inline

import pandas as pd
import numpy as np

import requests
import bs4

import re
import io

import wget
import ssl
ssl._create_default_https_context = ssl._create_unverified_context
import os.path

# %%
cols = ['Subregion and Country', 'Susp. Cases 2019', 'Measles Confirmed 2019 Clin.', 'Measles Confirmed 2019 Lab.',
        'Measles Confirmed 2019 Total', 'Year/Week Last Conf. Measles case', 'Rubella Confirmed 2019 Clin.',
        'Rubella Confirmed 2019 Lab.', 'Rubella Confirmed 2019 Total', 'Year/Week Last Conf. Rubella Case',
        'Diagnosis of Discarded Cases 2019 Dengue', 'Diagnosis of Discarded Cases 2019 Others',
        'Congenital Rubella Syndrome Susp.', 'Congenital Rubella Syndrome Conf.', 'Congenital Rubella Syndrome CRI*',
        'Year/Week Last Conf. CRS Case']

cols_w_epi = ['Subregion and Country', 'Susp. Cases 2019', 'Measles Confirmed 2019 Clin.',
        'Measles Confirmed 2019 Lab.', 'Measles Confirmed 2019 EPI', 'Measles Confirmed 2019 Total',
        'Year/Week Last Conf. Measles case', 'Rubella Confirmed 2019 Clin.', 'Rubella Confirmed 2019 Lab.',
        'Rubella Confirmed 2019 Total', 'Year/Week Last Conf. Rubella Case',
        'Diagnosis of Discarded Cases 2019 Dengue', 'Diagnosis of Discarded Cases 2019 Others',
        'Congenital Rubella Syndrome Susp.', 'Congenital Rubella Syndrome Conf.', 'Congenital Rubella Syndrome CRI*',
        'Year/Week Last Conf. CRS Case']

cols_extra = ['Subregion and Country', 'Susp. Cases 2019', 'Measles Confirmed 2019 Clin.',
        'Measles Confirmed 2019 Lab.', 'Measles Confirmed 2019 Total', 'Year/Week Last Conf. Measles case',
        'Rubella Confirmed 2019 Clin.', 'Rubella Confirmed 2019 Lab.', 'Rubella Confirmed 2019 Total',
        'Year/Week Last Conf. Rubella Case', 'Diagnosis of Discarded Cases 2019 Dengue', 'Remove',
        'Diagnosis of Discarded Cases 2019 Others', 'Congenital Rubella Syndrome Susp.',
        'Congenital Rubella Syndrome Conf.', 'Congenital Rubella Syndrome CRI*', 'Year/Week Last Conf. CRS Case']

new_cols = ['Subregion', 'Country', 'Susp. Cases 2019', 'Measles Confirmed 2019 Clin.',
        'Measles Confirmed 2019 Lab.', 'Measles Confirmed 2019 Total', 'Year/Week Last Conf. Measles case',
        'Rubella Confirmed 2019 Clin.', 'Rubella Confirmed 2019 Lab.', 'Rubella Confirmed 2019 Total',
        'Year/Week Last Conf. Rubella Case', 'Diagnosis of Discarded Cases 2019 Dengue',
        'Diagnosis of Discarded Cases 2019 Others', 'Congenital Rubella Syndrome Susp.',
        'Congenital Rubella Syndrome Conf.', 'Congenital Rubella Syndrome CRI*', 'Year/Week Last Conf. CRS Case']

cols_no_crs = ['Subregion and Country', 'Susp. Cases 2019', 'Measles Confirmed 2019 Clin.', 'Measles Confirmed 2019 Lab.',
        'Measles Confirmed 2019 Total', 'Year/Week Last Conf. Measles case', 'Rubella Confirmed 2019 Clin.',
        'Rubella Confirmed 2019 Lab.', 'Rubella Confirmed 2019 Total', 'Year/Week Last Conf. Rubella Case',
        'Diagnosis of Discarded Cases 2019 Dengue', 'Diagnosis of Discarded Cases 2019 Others',
        'Congenital Rubella Syndrome Susp.', 'Congenital Rubella Syndrome Conf.', 'Congenital Rubella Syndrome CRI*']

# %%
list_html = requests.get('https://www.paho.org/hq/index.php?option=com_content&view=article&id=730:2009-measlesrubella-weekly-bulletin&Itemid=39426&lang=en', verify=False).text
# Out:
# /Users/stephaniezhang/Library/Python/3.7/lib/python/site-packages/urllib3/connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,

# %%
list_soup = bs4.BeautifulSoup(list_html,'lxml')

# %%
match_2 = re.compile('Measles Rubella Weekly Bulletin \(([0-9]+-[0-9]+)\) -\s+(\d+) (\w+) (\d+)$')
match = re.compile('Measles.Rubella Weekly Bulletin \(([0-9]+)\) -\s+(\d+) (\w+) (\d+)$')
match_space = re.compile('Measles.Rubella Weekly Bulletin \(([0-9]+)\) -\s+(\d+) (\w+) (\d+) $')

# %%
report_list = []

# %%
for url in list_soup.find_all('a'):
    url_match = match_space.match(url.text) or match_2.match(url.text) or match.match(url.text)
    
    if url_match is not None:
        report_list.append(
            {
                'link': url.text,
                'url': url.get('href'),
                'issue': url_match.group(1),
                'day': url_match.group(2),
                'month': url_match.group(3),
                'year': url_match.group(4),               
            }
        )

# %%
for report in report_list:
    if int(report['year']) >= 2011:
        url = 'https://www.paho.org'+report['url']
        filename = f"Issue({report['issue']})-{report['month']} {report['day']}, {report['year']}.pdf"
        filepath = 'paho_pdfs/' + filename
        if not os.path.exists(filepath):
            wget.download(url, filepath)

# %%
def read_pdf(file):
    try:
        filepath = 'paho_pdfs/' + file
        
        tables = camelot.read_pdf(filepath, flavor='stream', edge_tol=500, row_tol=9, strip_text='\n', table_areas=['10, 360, 600, 90'])
        tables_low = camelot.read_pdf(filepath, flavor='stream', edge_tol=500, row_tol=9, strip_text='\n', table_areas=['10, 330, 600, 40'])
        tables_wide = camelot.read_pdf(filepath, flavor='stream', edge_tol=500, row_tol=7, strip_text='\n', table_areas=['30, 340, 620, 50'])
        
        #print(camelot.plot(tables_wide[0], kind='contour'))
        
        #TODO sometimes the table is in between tables and tables_low; it has 18 columns so it makes tables_low
        #the final_table, but then it cuts off the first few rows of the table
        #is ok for venezuela, but if expanding in the future will need to fix this
        
        #TODO sometimes it recognizes two lines as one and merges them so the values don't work anymore;
        #don't know how to fix this becuase has to do with how the table is being read not where it's being read
        
        table = tables[0].df
        table_low = tables_low[0].df
        table_wide = tables_wide[0].df
        final_table = None
        
        epi_flag = False
        
        
        if ('VEN' not in table_low.loc[:,0]) and ('VEN' not in table.loc[:,0]):
            final_table = table_wide
        else:
            if table.shape[1] == 17:
                final_table = table
            elif table.shape[1] == 16:
                final_table = table
            else:
                final_table = table_low
 
        #print(final_table.head(8))
        
        sep_flag = False
        
        try:
            data_start = final_table[final_table.loc[:, 0] == 'VEN'].index[0]
            data_end = final_table[final_table.loc[:, 0] == 'TOTAL'].index[0]
        except:
            sep_flag = True
            final_table.columns = new_cols
            data_start = final_table[final_table.loc[:, 1] == 'VEN'].index[0]
            data_end = final_table[final_table.loc[:, 1] == 'URY'].index[0]
        #^ the lines above will need to be changed when figure out how to not cut off top few rows
#         data_start = final_table[final_table.loc[:, 'Subregion and Country'] == 'AND BOL'].index[0]
        
        
        data = final_table.loc[data_start:data_end,:]
        
        if not (final_table.loc[11,11].isdigit() or final_table.loc[11,10] == '…'):
            data.columns = cols_extra
        elif final_table.shape[1] == 17:
            epi_flag = True
            data.columns = cols_w_epi
        elif final_table.shape[1] == 16:
            data.columns = cols
        elif final_table.shape[1] == 15:
            data.columns = cols_no_crs
        
        
        if not sep_flag:
            if epi_flag:
                ven_df = data.loc[(data['Subregion and Country'] == 'VEN'), ['Susp. Cases 2019', 'Measles Confirmed 2019 Clin.',
                                                            'Measles Confirmed 2019 Lab.', 'Measles Confirmed 2019 EPI',
                                                            'Measles Confirmed 2019 Total']]

            else:
                 ven_df = data.loc[(data['Subregion and Country'] == 'VEN'), ['Susp. Cases 2019', 'Measles Confirmed 2019 Clin.',
                                                            'Measles Confirmed 2019 Lab.', 'Measles Confirmed 2019 Total']]           
        elif sep_flag:
            ven_df = data.loc[(data['Country'] == 'VEN'), ['Susp. Cases 2019', 'Measles Confirmed 2019 Clin.',
                                                            'Measles Confirmed 2019 Lab.', 'Measles Confirmed 2019 Total']]          
        
        return list(ven_df.iloc[0, :].values)

    except Exception as e:
        print(e)
        return e

# %%
base_url = 'https://www.paho.org'

for report in report_list:
    if int(report['year']) >= 2011:
        filename = f"Issue({report['issue']})-{report['month']} {report['day']}, {report['year']}.pdf"
        #report['filename'] = filename

        #report['parse_result'] = read_pdf(base_url + report['url'], filename)

        values_list = read_pdf(filename)
        
        if isinstance(values_list, list):
            #print("length: " + str(len(values_list)))
            #print("list: " + str(values_list))
            print(filename)

            report['error'] = None
            #report['suspected_cases'] = values_list[0]
            #report['measles_confirmed_clin'] = values_list[1]
            #report['measles_confirmed_lab'] = values_list[2]
            total_index = None
            if len(values_list) == 5:
                #report['measles_confirmed_epi'] = values_list[3]
                total_index = 4
            else:
                #report['measles_confirmed_epi'] = None
                total_index = 3
            
            if values_list[total_index] == '…' or values_list[total_index] == '...':
                report['measles_confirmed_total'] = '...'
            else:
                total_val = values_list[total_index]
                nums = [int(i) for i in total_val if i.isdigit()] 
                func = lambda nums: int(''.join(str(i) for i in nums))
                total_num = func(nums)
                report['measles_confirmed_total'] = total_num

        else:
            report['error'] = values_list
            report['suspected_cases'] = None
            report['measles_confirmed_clin'] = None
            report['measles_confirmed_lab'] = None
            report['measles_confirmed_epi'] = None
            report['measles_confirmed_total'] = None
    else:
        break
# Out:
# Issue(02)-Jannuary 11, 2020.pdf
# Issue(01)-Jannuary 4, 2020.pdf
# Issue(52)-December 28, 2019.pdf
# Issue(50-51)-December 14, 2019.pdf
# Issue(49)-December 7, 2019.pdf
# Issue(48)-November 30, 2019.pdf
# Issue(47)-November 23, 2019.pdf
# Issue(46)-November 16, 2019.pdf
# Issue(45)-November 9, 2019.pdf
# Issue(44)-November 2, 2019.pdf
# Issue(43)-October 26, 2019.pdf
# Issue(42)-October 19, 2019.pdf
# Issue(41)-October 12, 2019.pdf
# Issue(40)-October 5, 2019.pdf
# Issue(39)-September 28, 2019.pdf
# Issue(38)-September 21, 2019.pdf
# Issue(37)-September 14, 2019.pdf
# Issue(36)-September 7, 2019.pdf
# Issue(35)-August 31, 2019.pdf
# Issue(34)-August 24, 2019.pdf
# Issue(33)-August 17, 2019.pdf
# Issue(32)-August 10, 2019.pdf
# Issue(31)-August 3, 2019.pdf
# Issue(30)-July 27, 2019.pdf
# Issue(29)-July 20, 2019.pdf
# Issue(28)-July 13, 2019.pdf
# Issue(27)-July 6, 2019.pdf
# Issue(26)-June 29, 2019.pdf
# Issue(25)-June 22, 2019.pdf
# Issue(24)-June 15, 2019.pdf
# Issue(23)-June 8, 2019.pdf
# Issue(22)-June 1, 2019.pdf
# Issue(21)-May 25, 2019.pdf
# Issue(20)-May 18, 2019.pdf
# Issue(19)-May 11, 2019.pdf
# Issue(18)-May 4, 2019.pdf
# Issue(17)-April 27, 2019.pdf
# Issue(16)-April 20, 2019.pdf
# Issue(15)-April 13, 2019.pdf
# Issue(14)-April 6, 2019.pdf
# Issue(13)-March 30, 2019.pdf
# Issue(12)-March 23, 2019.pdf
# Issue(11)-March 16, 2019.pdf
# Issue(10)-March 9, 2019.pdf
# Issue(09)-March 2, 2019.pdf
# Issue(08)-February 23, 2019.pdf
# Issue(07)-February 16, 2019.pdf
# Issue(06)-February 9, 2019.pdf
# Issue(05)-February 2, 2019.pdf
# Issue(04)-January 26, 2019.pdf
# Issue(03)-January 19, 2019.pdf
# Issue(02)-January 12, 2019.pdf
# Issue(01)-January 05, 2019.pdf
# Issue(52)-December 29, 2018.pdf
# Issue(50)-December 15, 2018.pdf
# Issue(49)-December 8, 2018.pdf
# Issue(48)-December 1, 2018.pdf
# Issue(46)-November 17, 2018.pdf
# Issue(45)-November 10, 2018.pdf
# Issue(47)-November 24, 2018.pdf
# Issue(44)-November 3, 2018.pdf
# Issue(43)-October 27, 2018.pdf
# Issue(42)-October 20, 2018.pdf
# Issue(41)-October 13, 2018.pdf
# Issue(40)-October 6, 2018.pdf
# Issue(39)-September 29, 2018.pdf
# Issue(38)-September 22, 2018.pdf
# Issue(37)-September 15, 2018.pdf
# Issue(36)-September 8, 2018.pdf
# Issue(35)-September 1, 2018.pdf
# Issue(34)-August 25, 2018.pdf
# Issue(33)-August 18, 2018.pdf
# Issue(32)-August 11, 2018.pdf
# Issue(31)-August 4, 2018.pdf
# Issue(30)-July 30, 2018.pdf
# Issue(29)-July 21, 2018.pdf
# Issue(28)-July 13, 2018.pdf
# Issue(26)-June 30, 2018.pdf
# Issue(24)-June 16, 2018.pdf
# Issue(23)-June 9, 2018.pdf
# Issue(22)-June 02, 2018.pdf
# Issue(21)-May 26, 2018.pdf
# Issue(20)-May 19, 2018.pdf
# Issue(19)-May 12, 2018.pdf
# Issue(18)-May 5, 2018.pdf
# Issue(17)-April 28, 2018.pdf
# Issue(16)-April 21, 2018.pdf
# Issue(15)-April 14, 2018.pdf
# Issue(15)-April 14, 2018.pdf
# Issue(14)-April 7, 2018.pdf
# Issue(13)-March 31, 2018.pdf
# Issue(12)-March 24, 2018.pdf
# Issue(11)-March 17, 2018.pdf
# Issue(10)-March 10, 2018.pdf
# Issue(09)-March 3, 2018.pdf
# Issue(08)-February 24, 2018.pdf
# Issue(07)-February 17, 2018.pdf
# Issue(06)-February 10, 2018.pdf
# Issue(05)-February 3, 2018.pdf
# Issue(04)-January 27, 2018.pdf
# Issue(03)-January 20, 2018.pdf
# Issue(02)-January 13, 2018.pdf
# Issue(52)-December 30, 2017.pdf
# Issue(51)-December 23, 2017.pdf
# Issue(50)-December 16, 2017.pdf
# Issue(49)-December 9, 2017.pdf
# Issue(48)-December 2, 2017.pdf
# Issue(47)-October 25, 2017.pdf
# Issue(45)-October 17, 2017.pdf
# Issue(44)-November 4, 2017.pdf
# Issue(43)-October 28, 2017.pdf
# Issue(42)-October 21, 2017.pdf
# Issue(41)-October 14, 2017.pdf
# Issue(40)-October 7, 2017.pdf
# Issue(39)-September 30, 2017.pdf
# Issue(38)-September 23, 2017.pdf
# Issue(37)-september 16, 2017.pdf
# Issue(36)-September 9, 2017.pdf
# Issue(35)-September 2, 2017.pdf
# Issue(34)-August 26, 2017.pdf
# Issue(33)-August 19, 2017.pdf
# Issue(32)-August 12, 2017.pdf
# Issue(31)-August 5, 2017.pdf
# Issue(30)-July 29, 2017.pdf
# Issue(29)-July 22, 2017.pdf
# Issue(28)-July 15, 2017.pdf
# Issue(27)-July 8, 2017.pdf
# Issue(26)-July 1, 2017.pdf
# Issue(25)-June 24, 2017.pdf
# Issue(24)-June 17, 2017.pdf
# Issue(23)-June 10, 2017.pdf
# Issue(22)-June 3, 2017.pdf
# Issue(21)-May 27, 2017.pdf
# Issue(20)-May 20, 2017.pdf
# Issue(19)-May 12, 2017.pdf
# Issue(18)-May 06, 2017.pdf
# Issue(17)-April 29, 2017.pdf
# Issue(16)-April 22, 2017.pdf
# Issue(15)-April 15, 2017.pdf
# Issue(14)-April 8, 2017.pdf
# Issue(13)-April 1, 2017.pdf
# Issue(12)-March 23, 2017.pdf
# Issue(11)-March 18, 2017.pdf
# Issue(10)-March 11, 2017.pdf
# Issue(9)-March 4, 2017.pdf
# Issue(8)-February 25, 2017.pdf
# Issue(7)-February 18, 2017.pdf
# Issue(6)-February 11, 2017.pdf
# Issue(5)-February 4, 2017.pdf
# Issue(4)-January 28, 2017.pdf
# Issue(3)-January 21, 2017.pdf
# Issue(2)-January 14, 2017.pdf
# Issue(1)-January 7, 2017.pdf
# Issue(52)-December 31, 2016.pdf
# Issue(51)-December 24, 2016.pdf
# Issue(50)-December 17, 2016.pdf
# Issue(49)-December 10, 2016.pdf
# Issue(48)-December 3, 2016.pdf
# Issue(47)-November 26, 2016.pdf
# Issue(46)-November 19, 2016.pdf
# Issue(45)-November 12, 2016.pdf
# Issue(44)-November 5, 2016.pdf
# Issue(43)-October 29, 2016.pdf
# Issue(42)-October 22, 2016.pdf
# Issue(41)-October 15, 2016.pdf
# Issue(40)-October 8, 2016.pdf
# Issue(39)-October 1, 2016.pdf
# cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [1] of <class 'int'>
# Issue(37)-September 17, 2016.pdf
# Issue(36)-September 10, 2016.pdf
# Issue(35)-September 3, 2016.pdf
# Issue(34)-August 27, 2016.pdf
# Issue(33)-August 20, 2016.pdf
# Issue(32)-August 13, 2016.pdf
# Issue(31)-August 6, 2016.pdf
# Issue(30)-July 30, 2016.pdf
# Issue(29)-July 23, 2016.pdf
# Issue(28)-July 16, 2016.pdf
# Issue(27)-July 9, 2016.pdf
# Issue(26)-July 2, 2016.pdf
# Issue(25)-June 25, 2016.pdf
# Issue(24)-June 18, 2016.pdf
# Issue(23)-June 11, 2016.pdf
# Issue(22)-June 4, 2016.pdf
# Issue(21)-May 28, 2016.pdf
# Issue(20)-May 21, 2016.pdf
# Issue(19)-May 14, 2016.pdf
# Issue(18)-May 7, 2016.pdf
# Issue(17)-April 30, 2016.pdf
# Issue(16)-April 23, 2016.pdf
# Issue(15)-April 16, 2016.pdf
# Issue(14)-April 9, 2016.pdf
# Issue(13)-April 2, 2016.pdf
# Issue(12)-March 26, 2016.pdf
# Issue(11)-March 19, 2016.pdf
# Issue(10)-March 12, 2016.pdf
# Issue(09)-March 05, 2016.pdf
# cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [1] of <class 'int'>
# Issue(07)-February 20, 2016.pdf
# Issue(06)-February 13, 2016.pdf
# Issue(05)-February 6, 2016.pdf
# Issue(04)-January 30, 2016.pdf
# Issue(03)-January 23, 2016.pdf
# Issue(02)-January 16, 2016.pdf
# Issue(01)-January 9, 2016.pdf
# Issue(52)-January 2, 2016.pdf
# Issue(51)-December 26, 2015.pdf
# Issue(49)-December 12, 2015.pdf
# Issue(48)-December 5, 2015.pdf
# Issue(47)-November 28, 2015.pdf
# Issue(46)-November 21, 2015.pdf
# Issue(45)-November 14, 2015.pdf
# Issue(44)-November 7, 2015.pdf
# Issue(43)-October 31, 2015.pdf
# Issue(42)-October 24, 2015.pdf
# Issue(41)-October 17, 2015.pdf
# Issue(40)-October 10, 2015.pdf
# Issue(39)-October 3, 2015.pdf
# Issue(38)-September 26, 2015.pdf
# Issue(37)-September 19, 2015.pdf
# Issue(36)-September 12, 2015.pdf
# Issue(35)-September 5, 2015.pdf
# Issue(34)-August 29, 2015.pdf
# Issue(33)-August 22, 2015.pdf
# Issue(32)-August 15, 2015.pdf
# Issue(31)-August 8, 2015.pdf
# Issue(30)-August 1, 2015.pdf
# Issue(29)-July 25, 2015.pdf
# Issue(28)-July 18, 2015.pdf
# Issue(27)-July 11, 2015.pdf
# Issue(26)-July 4, 2015.pdf
# Issue(25)-June 27, 2015.pdf
# Issue(24)-June 20, 2015.pdf
# Issue(23)-June 13, 2015.pdf
# Issue(22)-June 6, 2015.pdf
# Issue(21)-May 30, 2015.pdf
# Issue(20)-May 23, 2015.pdf
# Issue(19)-May 16, 2015.pdf
# Issue(18)-May 9, 2015.pdf
# Issue(17)-May 2, 2015.pdf
# Issue(16)-April 25, 2015.pdf
# Issue(15)-April 18, 2015.pdf
# Issue(14)-April 11, 2015.pdf
# Issue(13)-April 4, 2015.pdf
# Issue(12)-March 28, 2015.pdf
# Issue(11)-March 21, 2015.pdf
# Issue(10)-March 14, 2015.pdf
# Issue(09)-March 07, 2015.pdf
# Issue(08)-February 28, 2015.pdf
# Issue(07)-February 21, 2015.pdf
# Issue(06)-February 14, 2015.pdf
# Issue(05)-February 7, 2015.pdf
# Issue(04)-January 31, 2015.pdf
# Issue(03)-January 24, 2015.pdf
# Issue(02)-January 17, 2015.pdf
# Issue(01)-January 10, 2015.pdf
# Issue(53)-January 3, 2015.pdf
# Issue(52)-December 27, 2014.pdf
# Issue(51)-December 20, 2014.pdf
# Issue(50)-December 13, 2014.pdf
# Issue(49)-December 6, 2014.pdf
# Issue(48)-November 29, 2014.pdf
# Issue(47)-November 22, 2014.pdf
# Issue(46)-November 15, 2014.pdf
# Issue(45)-November 8, 2014.pdf
# Issue(44)-November 1, 2014.pdf
# Issue(43)-October 25, 2014.pdf
# Issue(42)-October 18, 2014.pdf
# Issue(41)-October 11, 2014.pdf
# Issue(40)-October 4, 2014.pdf
# Issue(39)-September 27, 2014.pdf
# Issue(38)-September 20, 2014.pdf
# Issue(37)-September 13, 2014.pdf
# Issue(36)-September 6, 2014.pdf
# Issue(35)-August 30, 2014.pdf
# Issue(34)-August 23, 2014.pdf
# Issue(33)-August 16, 2014.pdf
# Issue(32)-August 9, 2014.pdf
# Issue(31)-August 2, 2014.pdf
# Issue(30)-July 26, 2014.pdf
# Issue(29)-July 19, 2014.pdf
# Issue(28)-July 12, 2014.pdf
# Issue(27)-July 5, 2014.pdf
# Issue(26)-June 28, 2014.pdf
# Issue(25)-June 21, 2014.pdf
# Issue(24)-June 14, 2014.pdf
# Issue(23)-June 7, 2014.pdf
# cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [1] of <class 'int'>
# Issue(21)-May 24, 2014.pdf
# Issue(20)-May 17, 2014.pdf
# Issue(19)-May 10, 2014.pdf
# Issue(18)-May 3, 2014.pdf
# Issue(17)-April 26, 2014.pdf
# Issue(16)-April 19, 2014.pdf
# Issue(15)-April 12, 2014.pdf
# Issue(14)-April 5, 2014.pdf
# Issue(13)-March 29, 2014.pdf
# Issue(12)-March 22, 2014.pdf
# Issue(11)-March 15, 2014.pdf
# Issue(10)-March 8, 2014.pdf
# Issue(09)-March 1, 2014.pdf
# Issue(08)-February 22, 2014.pdf
# Issue(07)-February 15, 2014.pdf
# Issue(06)-February 8, 2014.pdf
# Issue(05)-February 1, 2014.pdf
# Issue(04)-January 25, 2014.pdf
# Issue(03)-January 18, 2014.pdf
# Issue(02)-January 11, 2014.pdf
# Issue(01)-January 4, 2014.pdf
# Issue(52)-December 28, 2013.pdf
# Issue(51)-December 21, 2013.pdf
# Issue(50)-December 14, 2013.pdf
# Issue(49)-December 7, 2013.pdf
# Issue(48)-November 30, 2013.pdf
# Issue(47)-November 23, 2013.pdf
# Issue(46)-November 16, 2013.pdf
# Issue(45)-November 09, 2013.pdf
# Issue(44)-November 2, 2013.pdf
# Issue(43)-October 26, 2013.pdf
# Issue(42)-October 19, 2013.pdf
# Issue(41)-October 12, 2013.pdf
# Issue(40)-October 5, 2013.pdf
# Issue(39)-September 28, 2013.pdf
# Issue(38)-September 21, 2013.pdf
# Issue(37)-September 14, 2013.pdf
# Issue(36)-September 7, 2013.pdf
# Issue(35)-August 31, 2013.pdf
# Issue(34)-August 24, 2013.pdf
# Issue(33)-August 17, 2013.pdf
# Issue(32)-August 10, 2013.pdf
# Issue(31)-August 3, 2013.pdf
# Issue(30)-July 27, 2013.pdf
# Issue(29)-July 20, 2013.pdf
# Issue(28)-July 13, 2013.pdf
# Issue(27)-July 6, 2013.pdf
# Issue(26)-June 29, 2013.pdf
# Issue(25)-June 22, 2013.pdf
# Issue(23)-June 8, 2013.pdf
# Issue(22)-June 1, 2013.pdf
# Issue(21)-May 25, 2013.pdf
# Issue(20)-May 18, 2013.pdf
# Issue(19)-May 11, 2013.pdf
# Issue(18)-May 4, 2013.pdf
# Issue(17)-April 27, 2013.pdf
# Issue(16)-April 20, 2013.pdf
# Issue(15)-April 13, 2013.pdf
# cannot do label indexing on <class 'pandas.core.indexes.base.Index'> with these indexers [1] of <class 'int'>
# Issue(13)-March 30, 2013.pdf
# Issue(12)-March 23, 2013.pdf
# Issue(11)-March 16, 2013.pdf
# Issue(10)-March 9, 2013.pdf
# Issue(09)-March 2, 2013.pdf
# Issue(08)-February 23, 2013.pdf
# Issue(07)-February 16, 2013.pdf
# Issue(06)-February 9, 2013.pdf
# Issue(05)-February 2, 2013.pdf
# Issue(04)-January 26, 2013.pdf
# Issue(03)-January 19, 2013.pdf
# Issue(02)-January 12, 2013.pdf
# Issue(01)-January 5, 2013.pdf
# Issue(52)-December 29, 2012.pdf
# Issue(51)-December 22, 2012.pdf
# Issue(50)-December 15, 2012.pdf
# Issue(49)-December 08, 2012.pdf
# Issue(48)-December 01, 2012.pdf
# Issue(47)-November 24, 2012.pdf
# Issue(46)-November 17, 2012.pdf
# Issue(45)-November 10, 2012.pdf
# Issue(44)-November 3, 2012.pdf
# Issue(43)-October 27, 2012.pdf
# Issue(42)-October 20, 2012.pdf
# Issue(41)-October 13, 2012.pdf
# Issue(40)-October 6, 2012.pdf
# Issue(39)-September 29, 2012.pdf
# Issue(38)-September 22, 2012.pdf
# Issue(37)-September 15, 2012.pdf
# Issue(36)-September 8, 2012.pdf
# Issue(35)-September 1, 2012.pdf
# Issue(34)-August 25, 2012.pdf
# Issue(33)-August 18, 2012.pdf
# Issue(32)-August 11, 2012.pdf
# Issue(31)-August 4, 2012.pdf
# Issue(30)-July 28, 2012.pdf
# Issue(29)-July 21, 2012.pdf
# Issue(28)-July 14, 2012.pdf
# Issue(27)-July 7, 2012.pdf
# Issue(26)-June 30, 2012.pdf
# Issue(25)-June 23, 2012.pdf
# Issue(24)-June 16, 2012.pdf
# Issue(23)-June 9, 2012.pdf
# Issue(22)-June 2, 2012.pdf
# Issue(21)-May 26, 2012.pdf
# Issue(20)-May 19, 2012.pdf
# Issue(19)-May 12, 2012.pdf
# Issue(17)-April 28, 2012.pdf
# Issue(16)-April 21, 2012.pdf
# Issue(15)-April 14, 2012.pdf
# Issue(14)-April 7, 2012.pdf
# Issue(13)-March 31, 2012.pdf
# Issue(12)-March 24, 2012.pdf
# Issue(11)-March 17, 2012.pdf
# Issue(10)-March 10, 2012.pdf
# Issue(09)-March 03, 2012.pdf
# Issue(08)-February 25, 2012.pdf
# Issue(07)-February 18, 2012.pdf
# Issue(06)-February 11, 2012.pdf
# Issue(05)-February 04, 2012.pdf
# Issue(04)-January 28, 2012.pdf
# Issue(03)-January 21, 2012.pdf
# Issue(02)-January 14, 2012.pdf
# Issue(01)-January 07, 2012.pdf
# Issue(52)-December 31, 2011.pdf
# Issue(51)-December 24, 2011.pdf
# Issue(50)-December 17, 2011.pdf
# Issue(49)-December 10, 2011.pdf
# Issue(48)-December 3, 2011.pdf
# Issue(47)-November 26, 2011.pdf
# Issue(46)-November 19, 2011.pdf
# Issue(45)-November 12, 2011.pdf
# Issue(44)-November 5, 2011.pdf
# Issue(43)-October 29, 2011.pdf
# Issue(42)-October 22, 2011.pdf
# Issue(41)-October 15, 2011.pdf
# Issue(40)-October 8, 2011.pdf
# Issue(38)-September 24, 2011.pdf
# Issue(37)-September 17, 2011.pdf
# Issue(36)-September 10, 2011.pdf
# Issue(35)-September 3, 2011.pdf
# Issue(34)-August 27, 2011.pdf
# Issue(33)-August 20, 2011.pdf
# Issue(32)-August 13, 2011.pdf
# Issue(31)-August 6, 2011.pdf
# Issue(30)-July 30, 2011.pdf
# Issue(29)-July 23, 2011.pdf
# Issue(28)-July 16, 2011.pdf
# Issue(27)-July 09, 2011.pdf
# Issue(26)-July 2, 2011.pdf
# Issue(25)-June 25, 2011.pdf
# Issue(24)-June 18, 2011.pdf
# Issue(22)-June 4, 2011.pdf
# Issue(19)-May 14, 2011.pdf
# Issue(18)-May 7, 2011.pdf
# Issue(17)-April 30, 2011.pdf
# Issue(16)-April 23, 2011.pdf
# Length mismatch: Expected axis has 18 elements, new values have 17 elements
# Issue(14)-April 9, 2011.pdf
# Issue(13)-April 2, 2011.pdf
# Issue(12)-March 26, 2011.pdf
# Issue(11)-March 19, 2011.pdf
# Issue(10)-March 12, 2011.pdf
# Issue(09)-March 5, 2011.pdf
# Issue(08)-February 26, 2011.pdf
# Issue(07)-February 19, 2011.pdf
# Issue(06)-February 12, 2011.pdf
# Issue(05)-February 5, 2011.pdf
# Issue(04)-Janaury 29, 2011.pdf
# Issue(03)-January 22, 2011.pdf
# Issue(02)-January 15, 2011.pdf
# Issue(01)-January 8, 2011.pdf
# Issue(52)-January 1, 2011.pdf

# %%
report_monthly = [
        {
            'monthname': f"{report_list[0]['month']} {report_list[0]['year']}",
            'month': report_list[0]['month'],
            'year': report_list[0]['year'],
            'cumulative_total': 0
        }
                ]
a = 0

for report in report_list:
    if int(report['year']) >= 2011:
        monthname = f"{report['month']} {report['year']}"
        
        if report_monthly[a]['monthname'] == monthname:
            if type(report['measles_confirmed_total']) == int:
                report_monthly[a]['cumulative_total'] = max(report_monthly[a]['cumulative_total'], report['measles_confirmed_total'])
            else:
                report_monthly[a]['cumulative_total'] = report_monthly[a]['cumulative_total']
        else:
            a += 1
            report_monthly.append({})
            report_monthly[a]['monthname'] = monthname
            report_monthly[a]['month'] = report['month']
            report_monthly[a]['year'] = report['year']
            if type(report['measles_confirmed_total']) == int:
                report_monthly[a]['cumulative_total'] = report['measles_confirmed_total']
            else:
                report_monthly[a]['cumulative_total'] = 0
    
    else:
        break

# %%
caseload_month = []
for i in range(len(report_monthly)):
    if report_monthly[i]['month'] == 'January' or report_monthly[i]['month'] == 'Jannuary':
        caseload_month.append(
                {
                    'month': report_monthly[i]['month'],
                    'year': report_monthly[i]['year'],
                    'caseload': report_monthly[i]['cumulative_total'],              
                }
            )
    
    else:
        caseload_month.append(
                {
                    'month': report_monthly[i]['month'],
                    'year': report_monthly[i]['year'],
                    'caseload': report_monthly[i]['cumulative_total']-report_monthly[i+1]['cumulative_total'],              
                }
            )

# %%
results_df = pd.DataFrame(report_list)
monthly_df = pd.DataFrame(caseload_month)

# %%
columns = ['issue', 'day', 'month', 'year', 'error', 'measles_confirmed_total']
results_df.loc[:, columns].to_csv('weekly_cumulative.csv', index=False)

# %%
monthly_df.to_csv('monthly_caseload.csv', index=False)
